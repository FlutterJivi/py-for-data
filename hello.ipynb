# %%
print("hello")
# Out:
# hello

# %%
print("my name is imran")
# Out:
# my name is imran

# %%
class Car:
  def __init__(self,color,model):
    self.color = color
    self.model = model

  def drive(self):
    print(f"{self.color} {self.model} is driving!")

my_car = Car("blue","Toyota")
my_car.drive
# Out:
# <bound method Car.drive of <__main__.Car object at 0x79e929957620>>
